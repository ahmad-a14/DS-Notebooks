# %%
lst = [1,2,[3,4],[5,[100,200,['hello']],23,11],1,7]

# %%
lst[3][1][2][0]
# Out:
# 'hello'

# %%
d = {'k1':[1,2,3,{'tricky':['oh','man','inception',{'target':[1,2,3,'hello']}]}]}

# %%
d['k1'][3]['tricky'][3]['target'][3]
# Out:
# 'hello'

# %% [markdown]
# ## Loading data into Pandas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline 

df = pd.read_csv('pokemon_data.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 12 columns]

# %% [markdown]
# ## Reading Data in Pandas

# %%
print(f'rows:{df.shape[0]}')
print(f'columns:{df.shape[1]}')
# Out:
# rows:800
# columns:12

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
#### Read Headers
cols = list(df.columns)
print(cols)
# Out:
# ['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary']

# %% [markdown]
# ## Sorting/Describing Data

# %% [markdown]
# Sort the dataframe ‘df’ with respect two keys, first with 'Type 1'in descending and then 'HP'in ascending.

# %%
df= df.sort_values(['Type 1', 'HP'], ascending=[0,1])

df
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
# 97    90                 Shellder  Water       NaN  30      65      100
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# ..   ...                      ...    ...       ...  ..     ...      ...
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# 734  666                 Vivillon    Bug    Flying  80      52       50
# 698  637                Volcarona    Bug      Fire  85      60       65
# 520  469                  Yanmega    Bug    Flying  86      76       86
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 139       15       20     80           1      False
# 381       10       55     80           3      False
# 97        45       25     40           1      False
# 106       25       25     50           1      False
# 125       70       25     60           1      False
# ..       ...      ...    ...         ...        ...
# 232       40      105     75           2      False
# 678      100       60    145           5      False
# 734       90       50     89           6      False
# 698      135      105    100           5      False
# 520      116       56     95           4      False
#
# [800 rows x 12 columns]

# %% [markdown]
# ## Making changes to the data
#
# Make changes in the dataframe df, so that you create a new column Total, which is the sum of the columns  'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed'.
# Rearrange the columns such that the output of the command

# %%
#df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']

# df = df.drop(columns=['Total'])

df['Total'] = df.iloc[:, 4:10].sum(axis=1)

cols = list(df.columns)
df = df[cols[0:4] + [cols[-1]]+cols[4:-1]]

df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
cols = list(df.columns)
cols
# Out:
# ['#',
#  'Name',
#  'Type 1',
#  'Type 2',
#  'HP',
#  'Attack',
#  'Defense',
#  'Sp. Atk',
#  'Sp. Def',
#  'Speed',
#  'Generation',
#  'Legendary',
#  'Total']

# %%
type([cols[-1]])
# Out:
# list

# %%
cols[0:4] + [cols[-1]]+cols[4:-1]
# Out:
# ['#',
#  'Name',
#  'Type 1',
#  'Type 2',
#  'Total',
#  'HP',
#  'Attack',
#  'Defense',
#  'Sp. Atk',
#  'Sp. Def',
#  'Speed',
#  'Generation',
#  'Legendary']

# %% [markdown]
# There are some ‘NaN’ values in the dataframe in various columns. Display the number of ‘NaN’ values in each columns

# %%
df.isna().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
cat_col = ['Name',
 'Type 1',
 'Type 2']
cat_col
# Out:
# ['Name', 'Type 1', 'Type 2']

# %%
for col in cat_col:
    print(col)
    print(df[col].value_counts())
# Out:
# Name
# Magikarp      1
# Magcargo      1
# Noivern       1
# Vulpix        1
# Charmander    1
#              ..
# Doduo         1
# Sentret       1
# Zigzagoon     1
# Bunnelby      1
# Yanmega       1
# Name: Name, Length: 800, dtype: int64
# Type 1
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Rock         44
# Electric     44
# Ground       32
# Dragon       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64
# Type 2
# Flying      97
# Ground      35
# Poison      34
# Psychic     33
# Fighting    26
# Grass       25
# Fairy       23
# Steel       22
# Dark        20
# Dragon      18
# Ghost       14
# Rock        14
# Ice         14
# Water       14
# Fire        12
# Electric     6
# Normal       4
# Bug          3
# Name: Type 2, dtype: int64

# %%
df['Type 1'].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Rock         44
# Electric     44
# Ground       32
# Dragon       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
df.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# Total          int64
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %%
df.mode()
# Out:
#          #                     Name Type 1  Type 2  Total    HP  Attack  \
# 0    479.0                Abomasnow  Water  Flying  600.0  60.0   100.0
# 1      NaN  AbomasnowMega Abomasnow    NaN     NaN    NaN   NaN     NaN
# 2      NaN                     Abra    NaN     NaN    NaN   NaN     NaN
# 3      NaN                    Absol    NaN     NaN    NaN   NaN     NaN
# 4      NaN          AbsolMega Absol    NaN     NaN    NaN   NaN     NaN
# ..     ...                      ...    ...     ...    ...   ...     ...
# 795    NaN                  Zoroark    NaN     NaN    NaN   NaN     NaN
# 796    NaN                    Zorua    NaN     NaN    NaN   NaN     NaN
# 797    NaN                    Zubat    NaN     NaN    NaN   NaN     NaN
# 798    NaN                 Zweilous    NaN     NaN    NaN   NaN     NaN
# 799    NaN         Zygarde50% Forme    NaN     NaN    NaN   NaN     NaN
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation Legendary
# 0       70.0     60.0     80.0   50.0         1.0     False
# 1        NaN      NaN      NaN    NaN         NaN       NaN
# 2        NaN      NaN      NaN    NaN         NaN       NaN
# 3        NaN      NaN      NaN    NaN         NaN       NaN
# 4        NaN      NaN      NaN    NaN         NaN       NaN
# ..       ...      ...      ...    ...         ...       ...
# 795      NaN      NaN      NaN    NaN         NaN       NaN
# 796      NaN      NaN      NaN    NaN         NaN       NaN
# 797      NaN      NaN      NaN    NaN         NaN       NaN
# 798      NaN      NaN      NaN    NaN         NaN       NaN
# 799      NaN      NaN      NaN    NaN         NaN       NaN
#
# [800 rows x 13 columns]

# %%
# df["Age"].fillna(df['Age'].mode()[0], inplace = True)
for col in cols:
    df[col].fillna(df[col].mode()[0], inplace = True)
df
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_23216\1280231065.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col].fillna(df[col].mode()[0], inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_23216\1280231065.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col].fillna(df[col].mode()[0], inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_23216\1280231065.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col].fillna(df[col].mode()[0], inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_23216\1280231065.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col].fillna(df[col].mode()[0], inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_23216\1280231065.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col].fillna(df[col].mode()[0], inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_23216\1280231065.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col].fillna(df[col].mode()[0], inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_23216\1280231065.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col].fillna(df[col].mode()[0], inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_23216\1280231065.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col].fillna(df[col].mode()[0], inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_23216\1280231065.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col].fillna(df[col].mode()[0], inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_23216\1280231065.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col].fillna(df[col].mode()[0], inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_23216\1280231065.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col].fillna(df[col].mode()[0], inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_23216\1280231065.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col].fillna(df[col].mode()[0], inplace = True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_23216\1280231065.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col].fillna(df[col].mode()[0], inplace = True)
#        #                     Name Type 1    Type 2  Total  HP  Attack  \
# 139  129                 Magikarp  Water    Flying    200  20      10
# 381  349                   Feebas  Water    Flying    200  20      15
# 97    90                 Shellder  Water    Flying    305  30      65
# 106   98                   Krabby  Water    Flying    325  30     105
# 125  116                   Horsea  Water    Flying    295  30      40
# ..   ...                      ...    ...       ...    ...  ..     ...
# 232  214  HeracrossMega Heracross    Bug  Fighting    600  80     185
# 678  617                 Accelgor    Bug    Flying    495  80      70
# 734  666                 Vivillon    Bug    Flying    411  80      52
# 698  637                Volcarona    Bug      Fire    550  85      60
# 520  469                  Yanmega    Bug    Flying    515  86      76
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 139       55       15       20     80           1      False
# 381       20       10       55     80           3      False
# 97       100       45       25     40           1      False
# 106       90       25       25     50           1      False
# 125       70       70       25     60           1      False
# ..       ...      ...      ...    ...         ...        ...
# 232      115       40      105     75           2      False
# 678       40      100       60    145           5      False
# 734       50       90       50     89           6      False
# 698       65      135      105    100           5      False
# 520       86      116       56     95           4      False
#
# [800 rows x 13 columns]

# %%
df[cols].fillna(df[cols].mode()[0], inplace = True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\miniconda3\envs\ds\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\miniconda3\envs\ds\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\miniconda3\envs\ds\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [29], line 1
# ----> 1 df[cols].fillna(df[cols].mode()[0], inplace = True)
#       2 df
#
# File ~\miniconda3\envs\ds\lib\site-packages\pandas\core\frame.py:3804, in DataFrame.__getitem__(self, key)
#    3802 if self.columns.nlevels > 1:
#    3803     return self._getitem_multilevel(key)
# -> 3804 indexer = self.columns.get_loc(key)
#    3805 if is_integer(indexer):
#    3806     indexer = [indexer]
#
# File ~\miniconda3\envs\ds\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 0

# %%
df.dtypes

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 13 columns]

# %%
if df['Attack'] >=100 and df['Total'] > 600:
    df['Legendary'] = True
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [5], line 1
# ----> 1 if df['Attack'] >=100 and df['Total'] > 600:
#       2     df['Legendary'] = True
#
# File ~\miniconda3\envs\ds\lib\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self) -> NoReturn:
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df.loc[(df['Attack']>=100) & (df['Total'] > 600), 'Legendary']=True
df
# Out:
#        #                     Name Type 1    Type 2  Total  HP  Attack  \
# 139  129                 Magikarp  Water    Flying    200  20      10
# 381  349                   Feebas  Water    Flying    200  20      15
# 97    90                 Shellder  Water    Flying    305  30      65
# 106   98                   Krabby  Water    Flying    325  30     105
# 125  116                   Horsea  Water    Flying    295  30      40
# ..   ...                      ...    ...       ...    ...  ..     ...
# 232  214  HeracrossMega Heracross    Bug  Fighting    600  80     185
# 678  617                 Accelgor    Bug    Flying    495  80      70
# 734  666                 Vivillon    Bug    Flying    411  80      52
# 698  637                Volcarona    Bug      Fire    550  85      60
# 520  469                  Yanmega    Bug    Flying    515  86      76
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 139       55       15       20     80           1      False
# 381       20       10       55     80           3      False
# 97       100       45       25     40           1      False
# 106       90       25       25     50           1      False
# 125       70       70       25     60           1      False
# ..       ...      ...      ...    ...         ...        ...
# 232      115       40      105     75           2      False
# 678       40      100       60    145           5      False
# 734       50       90       50     89           6      False
# 698       65      135      105    100           5      False
# 520       86      116       56     95           4      False
#
# [800 rows x 13 columns]

# %%
sns.displot(x= 'Total',data = df)

# %%
sns.displot(df['Total'])

# %%
df.groupby(['Type 1','Legendary'])['Total'].mean().plot.bar()
# Out:
# <AxesSubplot: xlabel='Type 1,Legendary'>

# %%
sns.barplot(y='Type 1', x='Total', hue='Legendary', data=df)
# Out:
# <AxesSubplot: xlabel='Total', ylabel='Type 1'>

# %%
df.groupby('Type 1')['Name'].count().sort_values(ascending=False).plot.bar()
# Out:
# <AxesSubplot: xlabel='Type 1'>

# %%
sns.boxplot(y='Type 1', x='Total', hue='Legendary', data=df)
# Out:
# <AxesSubplot: xlabel='Total', ylabel='Type 1'>

# %%
sns.countplot(y='Type 1', data=df)
# Out:
# <AxesSubplot: xlabel='count', ylabel='Type 1'>

# %%
sns.boxplot(y='Type 1', x ='Total', hue='Legendary', data=df, palette='rainbow')
# Out:
# <AxesSubplot: xlabel='Total', ylabel='Type 1'>

# %% [markdown]
# ## Saving our Data (Exporting into Desired Format)

# %%
# df.to_csv('modified.csv', index=False)

#df.to_excel('modified.xlsx', index=False)

df.to_csv('modified.txt', index=False, sep='\t')

# %% [markdown]
# ## Filtering Data

# %%
new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 70)]

new_df.reset_index(drop=True, inplace=True)

new_df

new_df.to_csv('filtered.csv')

# df.loc[~df['Name'].str.contains('Mega')]

# %% [markdown]
# ## Conditional Changes

# %%
# df.loc[df['Total'] > 500, ['Generation','Legendary']] = ['Test 1', 'Test 2']

# df

df = pd.read_csv('modified.csv')

df

# %% [markdown]
# ## Aggregate Statistics (Groupby)

# %%
df = pd.read_csv('modified.csv')

# df.groupby(['Type 1']).mean().sort_values('Defense',ascending=False)

df['count'] = 1

df.groupby(['Type 1', 'Type 2']).count()['count']

# %% [markdown]
# ## Working with large amounts of data

# %%
new_df = pd.DataFrame(columns=df.columns)

for df in pd.read_csv('modified.csv', chunksize=5):
    results = df.groupby(['Type 1']).count()
    
    new_df = pd.concat([new_df, results])
